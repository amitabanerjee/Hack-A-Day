# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Datasets/4. Example Data.csv')

# %%
data.head()
# Out:
#    monthly_salary  fico utilization  card_limit card_interest_rate  \
# 0           78780   897      13.17%       31032              3.75%
# 1           10065   794       6.22%       31697              3.41%
# 2           97434   880       8.44%       48998              9.68%
# 3          126755   729       0.73%       38827              4.14%
# 4           70696   624      15.47%        9082              5.51%
#
#    model_output  model_target
# 0        0.2231             0
# 1        0.9543             1
# 2        0.9906             0
# 3        0.0232             0
# 4        0.1075             0

# %%
dataset=pd.DataFrame(data)

# %%
df= pd.DataFrame(data)

# %%
dataset
# Out:
#      monthly_salary  fico utilization  card_limit card_interest_rate  \
# 0             78780   897      13.17%       31032              3.75%
# 1             10065   794       6.22%       31697              3.41%
# 2             97434   880       8.44%       48998              9.68%
# 3            126755   729       0.73%       38827              4.14%
# 4             70696   624      15.47%        9082              5.51%
# ..              ...   ...         ...         ...                ...
# 994           92808   767      14.30%       38832              7.28%
# 995           13853   823       0.54%       28031              9.54%
# 996          163112   726       1.06%       16501              2.34%
# 997          178632   725      13.92%       29530              4.94%
# 998          127292   823       9.51%       27206              6.98%
#
#      model_output  model_target
# 0          0.2231             0
# 1          0.9543             1
# 2          0.9906             0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   monthly_salary      999 non-null    int64
#  1   fico                999 non-null    int64
#  2   utilization         999 non-null    object
#  3   card_limit          999 non-null    int64
#  4   card_interest_rate  999 non-null    object
#  5   model_output        999 non-null    float64
#  6   model_target        999 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 54.8+ KB

# %%
dataset.describe()
# Out:
#        monthly_salary        fico    card_limit  model_output  model_target
# count      999.000000  999.000000    999.000000    999.000000    999.000000
# mean    105375.974975  751.919920  27660.368368      0.506357      0.252252
# std      55439.852673   88.454134  12794.068692      0.288941      0.434523
# min      10006.000000  600.000000   5033.000000      0.000700      0.000000
# 25%      58333.500000  673.500000  17269.500000      0.258000      0.000000
# 50%     106353.000000  755.000000  27829.000000      0.511300      0.000000
# 75%     155904.500000  828.000000  38435.000000      0.761550      1.000000
# max     199659.000000  900.000000  49867.000000      0.999900      1.000000

# %%
###EDA
##Correlation
data.corr()
# Out:
#                 monthly_salary      fico  card_limit  model_output  \
# monthly_salary        1.000000  0.002583   -0.026820     -0.017241
# fico                  0.002583  1.000000   -0.044355     -0.019602
# card_limit           -0.026820 -0.044355    1.000000      0.046312
# model_output         -0.017241 -0.019602    0.046312      1.000000
# model_target         -0.023137 -0.029559    0.023221      0.497377
#
#                 model_target
# monthly_salary     -0.023137
# fico               -0.029559
# card_limit          0.023221
# model_output        0.497377
# model_target        1.000000

# %%
import seaborn as sns
sns.pairplot(data)

# %%
plt.scatter(dataset['card_limit'],dataset['model_target'])
plt.xlabel=("card_limit")
plt.ylabel=("model_target")

# %%
plt.scatter(dataset['monthly_salary'],dataset['model_target'])
plt.xlabel=("card_limit")
plt.ylabel=("model_target")

# %%
plt.scatter(dataset['fico'],dataset['model_target'])
plt.xlabel=("card_limit")
plt.ylabel=("model_target")

# %%
plt.scatter(dataset['card_limit'],dataset['model_target'])
plt.xlabel=("card_limit")
plt.ylabel=("model_target")

# %%
import seaborn as sns 
sns.regplot(x="model_output", y="model_target", data=dataset)
# Out:
# <Axes: xlabel='model_output', ylabel='model_target'>

# %%
plt.hist(data['model_output'])
plt.title("Histogram of model outputs")
# Out:
# Text(0.5, 1.0, 'Histogram of model outputs')

# %%
import pickle

# %%
pickle.dump(data, open('/content/model_saved','wb'))

# %%
model_loaded=pickle.load(data, open('/content/model_saved','rb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-3c5f0c05efb8> in <module>
# ----> 1 model_loaded=pickle.load(data, open('/content/model_saved','rb'))
#
# TypeError: load() takes exactly 1 positional argument (2 given)

# %%
plt.hist(data['model_target'])
plt.title("Histogram of model targets")
# Out:
# Text(0.5, 1.0, 'Histogram of model targets')

# %%
plt.hist(data['card_interest_rate'])
plt.title("Histogram of card interest rate")
# Out:
# Text(0.5, 1.0, 'Histogram of card interest rate')

# %%
plt.hist(data['card_limit'])
plt.title("Histogram of card limit")
# Out:
# Text(0.5, 1.0, 'Histogram of card limit')

# %%
plt.hist(data['monthly_salary'])
plt.title("Histogram of monthly salary")
# Out:
# Text(0.5, 1.0, 'Histogram of monthly salary')

# %%
plt.hist(data['utilization'])
plt.title("Histogram of utilization")
# Out:
# Text(0.5, 1.0, 'Histogram of utilization')

# %%
confusion_matrix = pd.crosstab(df['model_output'], df['model_target'], rownames=['Actual'], colnames=['Predicted'])
print (confusion_matrix)
# Out:
# Predicted  0  1
# Actual
# 0.0007     1  0
# 0.0012     1  0
# 0.0020     1  0
# 0.0030     1  0
# 0.0036     1  0
# ...       .. ..
# 0.9964     1  0
# 0.9969     1  0
# 0.9993     1  1
# 0.9997     0  1
# 0.9999     0  1
#
# [940 rows x 2 columns]
